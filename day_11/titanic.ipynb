# %% [markdown]
# 1. titanic 데이터를 로드해서 전체 승객을 나이별로 히스토그램으로 나타내기 <br>
# 2. 남 녀 승객수 (countplot)

# %%
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False # - 기호 깨지는 것 방지
#f_path = '/Library/Fonts/AppleGothic.ttf'(맥)
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name() # - 글씨 깨지는 것 방지
rc('font', family=font_name)

# %%
import seaborn as sns
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# fig(기본틀), 그래프 격자(axes1)
import matplotlib.pyplot as plt
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)

# %%
axes1.hist(df['age'],bins=10)
# bins = 10 : x축의 간격을 10으로 조정
axes1.set_title('Histogram of Total Age')
axes1.set_xlabel('Age')
axes1.set_ylabel('Total')
fig

# %%
ax = plt.subplots()
ax = sns.countplot(x='sex',data=df)
ax.set_title('Count of clients')
ax.set_xlabel('Sex')
ax.set_ylabel('Total')
# Out:
# Text(0, 0.5, 'Total')

# %%
import matplotlib.pyplot as plt

labels = 'Frogs','Hogs','Dogs','Logs'
sizes = [15,30,45,10]
explode = (0,0.1,0,0)
#only "explode" the 2nd slice(i..3. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.1f%%',shadow=True,startangle = 90)
ax1.axis('equal')
plt.show()

# %%
labels='사망','생존'
sizes = [len(df[df['survived']==0]),len(df[df['survived']==1])]
explode = (0,0.1)

fig1, ax1 = plt.subplots()
ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.1f%%',shadow=True,startangle = 90)
ax1.axis('equal')  # 가로세로 비율 같게
ax1.set_title('사망 및 생존')
plt.show()
