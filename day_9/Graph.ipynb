# %% [markdown]
# ## 그래프

# %% [markdown]
# ### 앤스콤 데이터 집합 불러온 후 그래프 그리기

# %% [markdown]
# #### 1. 앤스콤 데이터 집합 불러오기

# %%
import seaborn as sns
anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))  #dataset 열이 데이터 그룹을 구분
# 평균, 분산,상관관계, 회귀선이 같다는 특징
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset']=='I']

# %%
print(dataset_1)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
#선 그래프는 plot 메서드로 그릴 수 있다. plot 메서드에 x,y축 데이터를 전달함
plt.plot(dataset_1['x'],dataset_1['y'])
plt.show()
#pylab 서브패키지 : matlab 수치해석 소프트웨어 시가고하 명령을 거의 그대로 사용
#plt.plot - 기본으로 설정된 Axes에서 Axes.plot() 를 호출하여 그림을 그림

# %%
# 점 그래프(세번째 인자에 o)
plt.plot(dataset_1['x'],dataset_1['y'],'o')

# %%
# 점 그래프(세번째 인자에 o)
plt.plot(dataset_1['x'],dataset_1['y'],'o',c='r')

# %%
plt.plot([1,4,9,16],c="b",lw = 5,ls="--",marker="o",ms=15,mec="g",mew=5,mfc="r")
plt.xlim(-0.2,3.2)
plt.ylim(-1,18)
plt.show()

# %%
# 틱 설정(축의 마커 설정)
import numpy as np
X = np.linspace(-np.pi,np.pi,256)
C = np.cos(X)
plt.plot(X,C)
plt.xticks([-np.pi,-np.pi/2,0,np.pi/2,np.pi])
plt.yticks([-1,0,+1])
plt.show()

# %% [markdown]
# ### 범례
# - 여러 개의 그래프가 표시될 경우 각 그래프를 설명하기 위한 도구
# - legent 함수 사용(loc 전달인자는 범례 표시 위치)

# %%
X= np.linspace(-np.pi,np.pi,256)
C,S = np.cos(X),np.sin(X)
plt.plot(X,C,label = "cosine")
plt.plot(X,S,label = "sine")
plt.legend(loc = 2)
plt.show()

# %% [markdown]
# ### matplotlib 라이브러리로 그래프 그리기
# - 1. 전체 그래프가 위치할 기본 특을 만들고
# - 2. 그래프를 그려 넣을 격자
# - 3. 겨자에 그래프를 하나씩 추가, 순서는 왼쪽 --> 오른쪽
# - 4. 1행이 차면 2번째 행에 그려 넣는다

# %%
dataset_2 = anscombe[anscombe['dataset']=='II']
dataset_3 = anscombe[anscombe['dataset']=='III']
dataset_4 = anscombe[anscombe['dataset']=='IV']

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2,2,1)   #행의 크기, 열의 크기, 순서
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %%
axes1.plot(dataset_1['x'],dataset_1['y'],'o')
axes2.plot(dataset_2['x'],dataset_2['y'],'o')
axes3.plot(dataset_3['x'],dataset_3['y'],'o')
axes4.plot(dataset_4['x'],dataset_4['y'],'o')
# 그래프 확인하려면 fig
fig

# %%
#제목 추가
axes1.set_title("datset_1")
axes2.set_title("datset_2")
axes3.set_title("datset_3")
axes4.set_title("datset_4")

fig

# %%
fig.suptitle("Anscombe Data")
fig

# %%
fig.tight_layout()
fig

# %% [markdown]
# ### 기초 그래프 그리기 - 히스토그램, 산점도, 박스 그래프

# %%
# 지불 금액, 팁, 성별, 흡연 여부, 요일, 시간, 전체 인원
tips = sns.load_dataset("tips")
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
# fig(기본틀), 그래프 격자(axes1)
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)

# %% [markdown]
# ### 1. 히스토그램은 df의 열 데이터 분포와 빈도를 살펴보는 용도로 자주 사용

# %% [markdown]
# 변수를 하나만 사용해서 그린 '일변량 그래프'

# %%
axes1.hist(tips['total_bill'],bins=10)
# bins = 10 : x축의 간격을 10으로 조정
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')
fig

# %% [markdown]
# ### 2. 산점도 그래프
# 변수 2개를 사용한 '이변량 그래프'-total_bill 열에 다른 tip 열의 분포를 나타낸 산점도 그래프

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'],tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### 3. 박스 그래프
#        *. 이산형 변수 - Female, Male처럼 명확하게 구분되는 값을 의미
#        *. 연속형 변수 - Tip와 같이 명확하게 셀 수 없는 변위의 값을 의미

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot(
                [tips[tips['sex'] == 'Female']['tip'],
                tips[tips['sex']=='Male']['tip']],
                labels = ['Female','Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# ### 다변량 데이터로 다변량 그래프 그리기 - 산점도 그래프
#         *. 다변량 - 3개 이상의 변수를 사용

# %%
# 성별을 새 변수로 추가
# 문자열은 산점도 그래프의 색상을 지정하는 값을 사용할 수 없다

def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_color
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0
# 1         10.34  1.66    Male     No   Sun  Dinner     3         1
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1
# 242       17.82  1.75    Male     No   Sat  Dinner     2         1
# 243       18.78  3.00  Female     No  Thur  Dinner     2         0
#
# [244 rows x 8 columns]

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
            x=tips['total_bill'],
            y=tips['tip'],
            s=tips['size']*10,
            c=tips['sex_color'],
            alpha=0.4)
#alpha = 투명도(0~1)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# # 단변량 그래프 그리기 - 히스토그램

# %% [markdown]
# seaborn 라이브러리는 matplotlib 라이브러리를 기반으로 만든 라이브러리

# %%
import seaborn as sns
tips = sns.load_dataset("tips")

# %% [markdown]
# ## seaborn 라이브러리로 히스토그램
# - seaborn라이브러리로 히스토그램을 그리려면 subplots, displot 메서드를 사용
# - distplot 메서드 : 기본 특 만듬 / total_bill 메서드 : total_bill 열데이터를 전달

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Desity Plot')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#밀집도(정규화시켜 넓이가 1이 되도록 그린 그래프) 제외
#Kernel Density Estimation(커널밀도 추정)
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'],kde=False)
ax.set_title('Total Bill Histogram with Desity Plot')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'],hist=False)
ax.set_title('Total Bill Histogram with Desity Plot')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#rug인자 추가 - 그래프의 축에 동일한 길이의 직선을 붙여
#데이터의 밀집 정도를 표현한 그래프
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'],rug = True)
ax.set_title('Total Bill Histogram with Rug Plot')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### count 그래프 - 이산값을 나타낸 그래프
# * 주로 범주형 변수의 분포를 파악할 때 사용
# * sns.countplot(x or y, data)

# %%
ax = plt.subplots()
ax = sns.countplot(x='day',data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots()
ax = sns.countplot(y='day',data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## 다양한 종류의 이변량 그래프 그리기

# %% [markdown]
# ### 1. seaborn 라이브러리로 산점도 그래프 그리기
# *. regplot 메서드를 사용하면 산점도 그래프와 회귀선을 그릴 수 있다

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill',y='tip',data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill',y='tip',data=tips,fit_reg=False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### 바 그래프 그리기

# %%
#barplot은 지정한 변수의 평균을 계산하여 그린다
#시간에 따라 지불한 비용의 평균을 바 그래프로 나타냄
ax = plt.subplots()
ax = sns.barplot(x='time',y='total_bill',data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %% [markdown]
# ### 박스 그래프 그리기

# %%
ax = plt.subplots()
ax = sns.boxplot(x='time',y='total_bill',data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time',y='total_bill',data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %% [markdown]
# ### 1. seaborn 라이브러리로 바이올린 그래프 그리기 - 색상 추가

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time',y='total_bill',hue='sex',\
                   data=tips,split=True)
plt.show()

# %%
import matplotlib.pyplot as plt

labels = 'Frogs','Hogs','Dogs','Logs'
sizes = [15,30,45,10]
explode = (0,0.1,0,0)
#only "explode" the 2nd slice(i..3. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.1f%%',shadow=True,startangle = 90)
ax1.axis('equal')
plt.show()

# %%
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False # - 기호 깨지는 것 방지
#f_path = '/Library/Fonts/AppleGothic.ttf'(맥)
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name() # - 글씨 깨지는 것 방지
rc('font', family=font_name)

# %%
import matplotlib.pyplot as plt

labels = '개구리','Hogs','Dogs','Logs'
sizes = [15,30,45,10]
explode = (0,0.1,0,0)
#only "explode" the 2nd slice(i..3. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.1f%%',shadow=True,startangle = 90)
ax1.axis('equal')
plt.show()
