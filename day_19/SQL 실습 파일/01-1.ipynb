# %% [markdown]
# #### 1. 2022년도 4/4분기 인구 현황

# %%
import pandas as pd

# %%
pop_seoul = pd.read_excel('../../data/python_data/주민등록인구_20230628105723.xlsx',header=1,usecols = 'B,C,D,E,F,G,H')
pop_seoul.head()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#   동별(2)  세대 (세대)        계      한국인   등록외국인  세대당인구  65세이상고령자
# 0    소계  4446296  9667669  9428372  239297   2.12   1667411
# 1   종로구    72524   152211   141379   10832   1.95     27958
# 2    중구    63139   130785   120437   10348   1.91     25055
# 3   용산구   109805   233284   218650   14634   1.99     39037
# 4   성동구   133305   288234   281000    7234   2.11     47720

# %%
pop_seoul.columns = ['구별','세대수','인구수','한국인','외국인','세대당인구','고령자']
pop_seoul.head(5)
# Out:
#     구별      세대수      인구수      한국인     외국인  세대당인구      고령자
# 0   소계  4446296  9667669  9428372  239297   2.12  1667411
# 1  종로구    72524   152211   141379   10832   1.95    27958
# 2   중구    63139   130785   120437   10348   1.91    25055
# 3  용산구   109805   233284   218650   14634   1.99    39037
# 4  성동구   133305   288234   281000    7234   2.11    47720

# %%
pop_seoul.drop([0],inplace=True)
pop_seoul.head()
# Out:
#     구별     세대수     인구수     한국인    외국인  세대당인구    고령자
# 1  종로구   72524  152211  141379  10832   1.95  27958
# 2   중구   63139  130785  120437  10348   1.91  25055
# 3  용산구  109805  233284  218650  14634   1.99  39037
# 4  성동구  133305  288234  281000   7234   2.11  47720
# 5  광진구  169291  351252  337416  13836   1.99  54071

# %%
pop_seoul[pop_seoul['구별'].isnull()]
# Out:
# Empty DataFrame
# Columns: [구별, 세대수, 인구수, 한국인, 외국인, 세대당인구, 고령자]
# Index: []

# %%
# 외국인비율과 고령자 비율
pop_seoul['외국인비율'] = pop_seoul['외국인']/pop_seoul['인구수'] * 100
pop_seoul['고령자비율'] = pop_seoul['고령자']/pop_seoul['인구수'] * 100
pop_seoul.head()
# Out:
#     구별     세대수     인구수     한국인    외국인  세대당인구    고령자     외국인비율      고령자비율
# 1  종로구   72524  152211  141379  10832   1.95  27958  7.116437  18.367923
# 2   중구   63139  130785  120437  10348   1.91  25055  7.912222  19.157396
# 3  용산구  109805  233284  218650  14634   1.99  39037  6.273041  16.733681
# 4  성동구  133305  288234  281000   7234   2.11  47720  2.509766  16.555993
# 5  광진구  169291  351252  337416  13836   1.99  54071  3.939052  15.393791

# %%
pop_seoul.sort_values(by='인구수',ascending=False).head(5)
# Out:
#      구별     세대수     인구수     한국인    외국인  세대당인구     고령자     외국인비율      고령자비율
# 24  송파구  284853  664514  658801   5713   2.31  103573  0.859726  15.586278
# 16  강서구  273697  574638  569166   5472   2.08   97128  0.952252  16.902467
# 23  강남구  232777  534103  529102   5001   2.27   81715  0.936336  15.299483
# 11  노원구  217540  508014  503734   4280   2.32   92040  0.842496  18.117611
# 21  관악구  283623  501226  486752  14474   1.72   82447  2.887719  16.449067

# %%
pop_seoul.sort_values(by='외국인',ascending=False).head(5)
# Out:
#       구별     세대수     인구수     한국인    외국인  세대당인구    고령자     외국인비율      고령자비율
# 17   구로구  183655  418418  395315  23103   2.15  75890  5.521512  18.137365
# 19  영등포구  188832  398085  375675  22410   1.99  64810  5.629451  16.280443
# 6   동대문구  169873  353601  336644  16957   1.98  64468  4.795518  18.231849
# 3    용산구  109805  233284  218650  14634   1.99  39037  6.273041  16.733681
# 21   관악구  283623  501226  486752  14474   1.72  82447  2.887719  16.449067

# %%
pop_seoul.sort_values(by='외국인비율',ascending=False).head(5)
# Out:
#       구별     세대수     인구수     한국인    외국인  세대당인구    고령자     외국인비율      고령자비율
# 2     중구   63139  130785  120437  10348   1.91  25055  7.912222  19.157396
# 1    종로구   72524  152211  141379  10832   1.95  27958  7.116437  18.367923
# 3    용산구  109805  233284  218650  14634   1.99  39037  6.273041  16.733681
# 19  영등포구  188832  398085  375675  22410   1.99  64810  5.629451  16.280443
# 17   구로구  183655  418418  395315  23103   2.15  75890  5.521512  18.137365

# %%
pop_seoul.sort_values(by='고령자',ascending=False).head(5)
# Out:
#      구별     세대수     인구수     한국인    외국인  세대당인구     고령자     외국인비율      고령자비율
# 24  송파구  284853  664514  658801   5713   2.31  103573  0.859726  15.586278
# 16  강서구  273697  574638  569166   5472   2.08   97128  0.952252  16.902467
# 11  노원구  217540  508014  503734   4280   2.32   92040  0.842496  18.117611
# 12  은평구  213876  470602  466746   3856   2.18   89650  0.819376  19.050068
# 21  관악구  283623  501226  486752  14474   1.72   82447  2.887719  16.449067

# %%
pop_seoul.sort_values(by='고령자비율',ascending=False).head(5)
# Out:
#      구별     세대수     인구수     한국인    외국인  세대당인구    고령자     외국인비율      고령자비율
# 9   강북구  144313  297702  293660   4042   2.03  66307  1.357734  22.272944
# 10  도봉구  138356  313989  311694   2295   2.25  66998  0.730917  21.337690
# 7   중랑구  187413  390140  385318   4822   2.06  74920  1.235967  19.203363
# 2    중구   63139  130785  120437  10348   1.91  25055  7.912222  19.157396
# 12  은평구  213876  470602  466746   3856   2.18  89650  0.819376  19.050068

# %% [markdown]
# #### 2. CCTV 관련 최근 3년간 증가율

# %%
df_cctv = pd.read_csv('../../data/python_data/서울시 자치구 년도별 CCTV 설치 현황_221231기준.csv',encoding='cp949',thousands=',')
df_cctv.head(3)
# Out:
#     구분     총계  2013년 이전\n설치된 CCTV  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  91341                2804   3097   3981   6576   8850  11566  11024
# 1  종로구   1980                  36    540    107    161    131    158    152
# 2  중 구   2584                 130     87     77    236    240    372    386
#
#    2019년  ...  Unnamed: 16374  Unnamed: 16375  Unnamed: 16376  Unnamed: 16377  \
# 0  13151  ...             NaN             NaN             NaN             NaN
# 1     69  ...             NaN             NaN             NaN             NaN
# 2    155  ...             NaN             NaN             NaN             NaN
#
#    Unnamed: 16378  Unnamed: 16379  Unnamed: 16380  Unnamed: 16381  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
#
#    Unnamed: 16382  Unnamed: 16383
# 0             NaN             NaN
# ...

# %%
df = df_cctv.iloc[:,0:13]
df.head(5)
# Out:
#     구분     총계  2013년 이전\n설치된 CCTV  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  91341                2804   3097   3981   6576   8850  11566  11024
# 1  종로구   1980                  36    540    107    161    131    158    152
# 2  중 구   2584                 130     87     77    236    240    372    386
# 3  용산구   2847                  44     50     68     83    295    491    115
# 4  성동구   4047                  58     99    110    366    279    945    459
#
#    2019년  2020년  2021년  2022년
# 0  13151  11912   9144   9236
# 1     69    250     85    291
# 2    155    361    403    137
# 3    322    623    422    334
# 4    647    485    367    232

# %%
df.columns = ['구별','합계','2013년이전','2013년','2014년','2015년','2016년','2017년','2018년','2019년','2020년','2021년','2022년']
df.head(5)
# Out:
#     구별     합계  2013년이전  2013년  2014년  2015년  2016년  2017년  2018년  2019년  \
# 0    계  91341     2804   3097   3981   6576   8850  11566  11024  13151
# 1  종로구   1980       36    540    107    161    131    158    152     69
# 2  중 구   2584      130     87     77    236    240    372    386    155
# 3  용산구   2847       44     50     68     83    295    491    115    322
# 4  성동구   4047       58     99    110    366    279    945    459    647
#
#    2020년  2021년  2022년
# 0  11912   9144   9236
# 1    250     85    291
# 2    361    403    137
# 3    623    422    334
# 4    485    367    232

# %%
df.drop([0],inplace=True)
df.head()
# Out:
#     구별    합계  2013년이전  2013년  2014년  2015년  2016년  2017년  2018년  2019년  2020년  \
# 1  종로구  1980       36    540    107    161    131    158    152     69    250
# 2  중 구  2584      130     87     77    236    240    372    386    155    361
# 3  용산구  2847       44     50     68     83    295    491    115    322    623
# 4  성동구  4047       58     99    110    366    279    945    459    647    485
# 5  광진구  3480      507     82     84     64     21    465    443    709    172
#
#    2021년  2022년
# 1     85    291
# 2    403    137
# 3    422    334
# 4    367    232
# 5    662    271

# %%
df['2019년이후'] = df['합계'] - (df['2021년'] + df['2020년'] + df['2022년'])
df.head()
# Out:
#     구별    합계  2013년이전  2013년  2014년  2015년  2016년  2017년  2018년  2019년  2020년  \
# 1  종로구  1980       36    540    107    161    131    158    152     69    250
# 2  중 구  2584      130     87     77    236    240    372    386    155    361
# 3  용산구  2847       44     50     68     83    295    491    115    322    623
# 4  성동구  4047       58     99    110    366    279    945    459    647    485
# 5  광진구  3480      507     82     84     64     21    465    443    709    172
#
#    2021년  2022년  2019년이후
# 1     85    291     1354
# 2    403    137     1683
# 3    422    334     1468
# 4    367    232     2963
# 5    662    271     2375

# %%
df['최근증가율'] = (df['2020년']+ df['2021년']+ df['2022년']) / df['2019년이후']
df.head()
# Out:
#     구별    합계  2013년이전  2013년  2014년  2015년  2016년  2017년  2018년  2019년  2020년  \
# 1  종로구  1980       36    540    107    161    131    158    152     69    250
# 2  중 구  2584      130     87     77    236    240    372    386    155    361
# 3  용산구  2847       44     50     68     83    295    491    115    322    623
# 4  성동구  4047       58     99    110    366    279    945    459    647    485
# 5  광진구  3480      507     82     84     64     21    465    443    709    172
#
#    2021년  2022년  2019년이후     최근증가율
# 1     85    291     1354  0.462334
# 2    403    137     1683  0.535354
# 3    422    334     1468  0.939373
# 4    367    232     2963  0.365845
# 5    662    271     2375  0.465263

# %% [markdown]
# #### 3. CCTV와 인구 관련 상관관계가 가장 높은 요소를 찾아내고 그래프 그리기

# %%
data_result = pd.merge(pop_seoul,df,on='구별')
data_result
# Out:
#       구별     세대수     인구수     한국인    외국인  세대당인구     고령자     외국인비율      고령자비율  \
# 0    종로구   72524  152211  141379  10832   1.95   27958  7.116437  18.367923
# 1    용산구  109805  233284  218650  14634   1.99   39037  6.273041  16.733681
# 2    성동구  133305  288234  281000   7234   2.11   47720  2.509766  16.555993
# 3    광진구  169291  351252  337416  13836   1.99   54071  3.939052  15.393791
# 4   동대문구  169873  353601  336644  16957   1.98   64468  4.795518  18.231849
# 5    중랑구  187413  390140  385318   4822   2.06   74920  1.235967  19.203363
# 6    성북구  197082  441984  430397  11587   2.18   77475  2.621588  17.528915
# 7    강북구  144313  297702  293660   4042   2.03   66307  1.357734  22.272944
# 8    도봉구  138356  313989  311694   2295   2.25   66998  0.730917  21.337690
# 9    노원구  217540  508014  503734   4280   2.32   92040  0.842496  18.117611
# 10   은평구  213876  470602  466746   3856   2.18   89650  0.819376  19.050068
# ...

# %%
data_result.sort_values(by='합계',ascending=False).head(5)
# Out:
#         세대수     인구수     한국인    외국인  세대당인구    고령자     외국인비율      고령자비율    합계  \
# 구별
# 강남구  232777  534103  529102   5001   2.27  81715  0.936336  15.299483  7243
# 관악구  283623  501226  486752  14474   1.72  82447  2.887719  16.449067  5398
# 서초구  167749  408451  404325   4126   2.41  62347  1.010158  15.264254  4995
# 성북구  197082  441984  430397  11587   2.18  77475  2.621588  17.528915  4842
# 구로구  183655  418418  395315  23103   2.15  75890  5.521512  18.137365  4693
#
#      2013년이전  ...  2017년  2018년  2019년  2020년  2021년  2022년  2019년이후  \
# 구별            ...
# 강남구       59  ...    989    744    790    923    514    468     5338
# 관악구      362  ...    676    662    890    404    550    164     4280
# 서초구       74  ...   1054    426    344    422    566    876     3131
# 성북구      137  ...    811    867    714    253    407    338     3844
# 구로구       37  ...    563    545    794    651    684    243     3115
#
#         최근증가율    CCTV비율           오차
# 구별
# ...

# %%
data_result.set_index('구별',inplace=True)
data_result.head()
# Out:
#          세대수     인구수     한국인    외국인  세대당인구    고령자     외국인비율      고령자비율    합계  \
# 구별
# 종로구    72524  152211  141379  10832   1.95  27958  7.116437  18.367923  1980
# 용산구   109805  233284  218650  14634   1.99  39037  6.273041  16.733681  2847
# 성동구   133305  288234  281000   7234   2.11  47720  2.509766  16.555993  4047
# 광진구   169291  351252  337416  13836   1.99  54071  3.939052  15.393791  3480
# 동대문구  169873  353601  336644  16957   1.98  64468  4.795518  18.231849  2759
#
#       2013년이전  ...  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년  \
# 구별             ...
# 종로구        36  ...    161    131    158    152     69    250     85    291
# 용산구        44  ...     83    295    491    115    322    623    422    334
# 성동구        58  ...    366    279    945    459    647    485    367    232
# 광진구       507  ...     64     21    465    443    709    172    662    271
# 동대문구        1  ...    107    802    711    201    218    223    221    259
#
#       2019년이후     최근증가율
# ...

# %% [markdown]
# 상관계수 구하기

# %%
import numpy as np
np.corrcoef(data_result['한국인'],data_result['합계'])
# Out:
# array([[1.       , 0.4277684],
#        [0.4277684, 1.       ]])

# %%
np.corrcoef(data_result['고령자비율'],data_result['합계'])
# Out:
# array([[ 1.        , -0.31763674],
#        [-0.31763674,  1.        ]])

# %%
np.corrcoef(data_result['인구수'],data_result['합계'])
# Out:
# array([[1.        , 0.43619981],
#        [0.43619981, 1.        ]])

# %%
np.corrcoef(data_result['세대수'],data_result['합계'])
# cctv와 상관관계 높은것을 이거로 결정함
# Out:
# array([[1.        , 0.44553896],
#        [0.44553896, 1.        ]])

# %%
np.corrcoef(data_result['외국인'],data_result['합계'])
# Out:
# array([[1.        , 0.03750341],
#        [0.03750341, 1.        ]])

# %%
np.corrcoef(data_result['세대당인구'],data_result['합계'])
# Out:
# array([[1.        , 0.15262508],
#        [0.15262508, 1.        ]])

# %%
np.corrcoef(data_result['최근증가율'],data_result['합계'])
# Out:
# array([[ 1.        , -0.31103277],
#        [-0.31103277,  1.        ]])

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False # - 기호 깨지는 것 방지
#f_path = '/Library/Fonts/AppleGothic.ttf'(맥)
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name() # - 글씨 깨지는 것 방지
rc('font', family=font_name)

# %%
data_result['CCTV비율'] = data_result['합계']/data_result['인구수']*100

data_result['CCTV비율'].sort_values().plot(kind='barh',grid=True,figsize=(10,10))

plt.show()

# %%
data_result['최근증가율'].sort_values().plot(kind='barh',grid=True,figsize=(10,10))

plt.show()

# %%
import numpy as np

fp1 = np.polyfit(data_result['세대수'],data_result['합계'],1)
fp1
# Out:
# array([1.02443526e-02, 1.82726642e+03])

# %%
f1 = np.poly1d(fp1)
fx = np.linspace(0,100000,10)

# %%
plt.figure(figsize=(10,10))
plt.scatter(data_result['세대수'],data_result['합계'],s=50)
plt.plot(fx, f1(fx), ls = 'dashed',lw=3,color='g')
plt.xlabel('세대수')
plt.ylabel('합계')
plt.grid()
plt.show()

# %%
fp1 = np.polyfit(data_result['세대수'],data_result['최근증가율'],1)

f1 = np.poly1d(fp1)
fx = np.linspace(100000,700000,100)

data_result['오차']= np.abs(data_result['합계']-f1(data_result['세대수']))

df_sort = data_result.sort_values(by='오차',ascending=False)
df_sort.head(10)
# Out:
#          세대수     인구수     한국인    외국인  세대당인구    고령자     외국인비율      고령자비율    합계  \
# 구별
# 강남구   232777  534103  529102   5001   2.27  81715  0.936336  15.299483  7243
# 관악구   283623  501226  486752  14474   1.72  82447  2.887719  16.449067  5398
# 서초구   167749  408451  404325   4126   2.41  62347  1.010158  15.264254  4995
# 성북구   197082  441984  430397  11587   2.18  77475  2.621588  17.528915  4842
# 구로구   183655  418418  395315  23103   2.15  75890  5.521512  18.137365  4693
# 은평구   213876  470602  466746   3856   2.18  89650  0.819376  19.050068  4653
# 영등포구  188832  398085  375675  22410   1.99  64810  5.629451  16.280443  4553
# 중랑구   187413  390140  385318   4822   2.06  74920  1.235967  19.203363  4193
# 성동구   133305  288234  281000   7234   2.11  47720  2.509766  16.555993  4047
# 양천구   181187  444010  440881   3129   2.43  72393  0.704714  16.304363  3851
#
#       2013년이전  ...  2017년  2018년  2019년  2020년  2021년  2022년  2019년이후  \
# 구별             ...
# ...

# %%
plt.figure(figsize=(14,10))
plt.scatter(data_result['세대수'],data_result['합계'],c=data_result['오차'],s=50)
plt.plot(fx, f1(fx), ls = 'dashed',lw=3,color='g')

for n in range(10):
    plt.text(df_sort['세대수'][n]*1.02, df_sort['합계'][n]*0.98,df_sort.index[n],fontsize=15)
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.colorbar()
plt.grid()
plt.show()
